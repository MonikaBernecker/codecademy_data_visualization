# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load data
df = pd.read_csv("E:/Codecademy_Projekte/codecademy_portfolio_projects/Life-Expectancy-and-GDP-Starter/all_data.csv")

# Explore Data
print(df.head())
print(df.info())
print(df.columns)

# Check for missing values
print(df.isnull().sum())

# Variation of Life expectancy for each country over time

fig, ax = plt.subplots(figsize=(10, 6))

countries = df['Country'].unique()

for country in countries:
    data = df[df['Country'] == country]
    ax.plot(data['Year'], data['Life expectancy at birth (years)'], label=country)

ax.set_title('Variation of Life expectancy for each country over time', fontsize=16)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Life expectancy at birth (years)', fontsize=12)

ax.legend(title='Country')

plt.show()
plt.clf()

# Variation of the GDP over time for each country
fig, ax = plt.subplots(figsize=(10, 6))

countries = df['Country'].unique()

for country in countries:
    data = df[df['Country'] == country]
    ax.plot(data['Year'], data['GDP'], label=country)

ax.set_title('Variation of GDP for each country over time', fontsize=16)
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('GDP', fontsize=12)

ax.legend(title='Country')

plt.show()
plt.clf()

# Is there a correlation between GDP and life expectancy of a country?

plt.figure(figsize=(10, 6))
sns.scatterplot(x="GDP", y="Life expectancy at birth (years)", data=df, hue="Country")
plt.xlabel('GDP in U.S. dollars')
plt.ylabel('Life Expectancy at Birth (years)')
plt.title("Scatter Plot of GDP vs. Life Expectancy")
plt.legend(title='Country', fontsize='small', loc='best')
plt.show()
plt.clf()

for country in df['Country'].unique():
    country_data = df[df['Country'] == country]
    correlation = country_data['GDP'].corr(country_data['Life expectancy at birth (years)'])
    print(f"The Pearson-correlation coefficient for {country} is: {correlation:.2f}")


# correlation between GDP and life expactancy in Zimbabwe
import seaborn as sns
import matplotlib.pyplot as plt

zimbabwe_data = df[df['Country'] == 'Zimbabwe']

sns.scatterplot(x="GDP", y="Life expectancy at birth (years)", data=zimbabwe_data)

plt.xlabel('GDP')
plt.ylabel('Life expectancy at birth (years)')
plt.title("GDP vs. Life Expectancy for Zimbabwe")

plt.show()
plt.clf()

# Average life expectancy for each country
average_life_expectancy = df.groupby(['Country'])["Life expectancy at birth (years)"].mean().reset_index()
print(average_life_expectancy)

import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
sns.barplot(x="Country", y="Life expectancy at birth (years)", data=average_life_expectancy)

plt.xlabel('Country')
plt.ylabel('Average Life expectancy at birth (years)')
plt.title("Average Life Expectancy for Each Country")

plt.xticks(rotation=45)

plt.show()
plt.clf()

# distribution of the life expectancy for each country

plt.figure(figsize=(12, 8))
sns.boxplot(x="Country", y="Life expectancy at birth (years)", data=df)
plt.xticks(rotation=45)
plt.title('distribution of the life expectancy')
plt.show()
plt.clf()


plt.figure(figsize=(15, 8))

countries = df['Country'].unique()
for country in countries:
    subset = df[df['Country'] == country]
    sns.histplot(subset['Life expectancy at birth (years)'], kde=False, label=country, alpha=0.6, bins=15)

    plt.title('distribution of the life expectancy for each country')
    plt.xlabel('Life expectancy at birth (years)')
    plt.ylabel('Count')
    plt.legend(title='Country')
    plt.show()
    plt.clf()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
# None
# ...
